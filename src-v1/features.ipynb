# %%
# %load_ext autoreload
# %autoreload 2
import copper
copper.project.path = '..'

# %%
train = copper.load('train')

# %%
train.features_weight().head(10)
# Out:
# 14    1.000000
# 12    0.929316
# 18    0.351468
# 39    0.294075
# 6     0.269104
# 34    0.235248
# 36    0.226864
# 32    0.218048
# 28    0.184287
# 23    0.130328

# %%
train.RCE_rank().head(10)
# Out:
# 16    21
# 35    20
# 10    19
# 24    18
# 5     17
# 30    16
# 3     15
# 8     14
# 7     13
# 28    12

# %%
train.scatter_pca()
