# %%
# %load_ext autoreload
# %autoreload 2
import copper
import numpy as np
import pandas as pd
copper.project.path = '..'
plt.rcParams['figure.figsize'] = 10, 7.55

# %%
train = copper.load('train')

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier()

# %% [markdown]
# ## n_estimators

# %%
values = [10, 20, 50, 100, 200]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'n_estimators', values, n_iter=10, random_state=12345)

# %%
copper.plot.grid(values, train_scores, test_scores)

# %% [markdown]
# ## Max depth

# %%
clf = GradientBoostingClassifier(n_estimators=100)

# %%
values = [3,6,9,12,15]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'max_depth', values, n_iter=5, random_state=12345)

# %%
copper.plot.grid(values, train_scores, test_scores)

# %% [markdown]
# ## Min samples split

# %%
clf = GradientBoostingClassifier(n_estimators=100, max_depth=6)

# %%
values = [2,3,4,5,6]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'min_samples_split', values, n_iter=5, random_state=12345)

# %%
copper.plot.grid(values, train_scores, test_scores)

# %% [markdown]
# ## learning_rate

# %%
clf = GradientBoostingClassifier(n_estimators=100, max_depth=6, min_samples_split=4)

# %%
values = [0.001,0.1,0.2,0.5]

# %%
train_scores, test_scores = copper.utils.ml.grid(train, clf, 'learning_rate', values, n_iter=5, random_state=12345)

# %%
copper.plot.grid(values, train_scores, test_scores)
